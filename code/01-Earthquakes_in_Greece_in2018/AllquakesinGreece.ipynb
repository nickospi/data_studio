# %% [markdown]
# ## Project 1 : Earthquakes in Greece in 2018

# %% [markdown]
# ### I have found this set http://www.geophysics.geol.uoa.gr/stations/maps/recent.html from the Geophysics Dept. of the University of Athens, Greece. It contains geographical, chronological and earthquake measuring data from 01.01.2018 until today.

# %%
import pandas as pd
import matplotlib
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("event_output.tsv", delimiter=" ")
df.head()
# Out:
#    Year  Mo  Dy  Hr  Mn    Sec  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0  2018   7  10  15  29  15.91         NaN     37.6361         NaN
# 1  2018   7  10  12  44  45.51         NaN     35.8716         NaN
# 2  2018   7  10  11  51  25.69         NaN     38.5067         NaN
# 3  2018   7  10   5  32  47.32         NaN     38.3658         NaN
# 4  2018   7  10   5  18  19.65         NaN     38.5995         NaN
#
#    Unnamed: 9 ...   Unnamed: 45  Unnamed: 46  Unnamed: 47  dz  Unnamed: 49  \
# 0         NaN ...           NaN          NaN          NaN NaN          NaN
# 1         NaN ...           NaN          NaN          NaN NaN          NaN
# 2         NaN ...           NaN          NaN          NaN NaN          NaN
# 3         NaN ...           NaN          NaN          NaN NaN          NaN
# 4         NaN ...           NaN          NaN          NaN NaN          NaN
#
#    Unnamed: 50  Np  Unnamed: 52  Na  Gap
# 0          NaN NaN          NaN NaN  NaN
# 1          NaN NaN          NaN NaN  NaN
# 2          NaN NaN          NaN NaN  NaN
# 3          NaN NaN          NaN NaN  NaN
# 4          NaN NaN          NaN NaN  NaN
#
# [5 rows x 55 columns]

# %% [markdown]
# ### A word on cleaning: I got this as a .tsv file straight from the above url, I opened it in pandas and got 55 columns which had 2 main issues: some of them were completely full of NaN values and had to be dropped, whereas some series from the original had split data in 2 columns [eg. on index 0, I got magnitude level in column 15 and on index 1 in column 16] so I had to merge these and drop NaNs]

# %%
pd.set_option('display.max_columns', 500)

# %%
df.drop(['Unnamed: 6', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 49','Unnamed: 50'], axis=1, inplace=True)

# %%
df.drop(['Lat', 'Unnamed: 12', 'Unnamed: 41', 'Unnamed: 42','Unnamed: 43','Unnamed: 52','Na','Gap','Np','dy','dz','dx'], axis=1, inplace=True)

# %%
df.drop(['Unnamed: 38', 'Unnamed: 39'], axis=1, inplace=True)

# %%
df.drop(['Long', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23',"Dep"], axis=1, inplace=True)

# %%
df ['mag'] = df['Unnamed: 15'].combine_first(df['Unnamed: 16'])

# %%
df.drop(['Unnamed: 15', 'Unnamed: 16'], axis=1, inplace=True)

# %%
df ['depth'] = df['Unnamed: 13'].combine_first(df['Unnamed: 14'])

# %%
df.drop(['Unnamed: 13', 'Unnamed: 14'], axis=1, inplace=True)

# %%
df.drop(['Mag', 'Unnamed: 25','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30', 'Unnamed: 31','Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','RMS'], axis=1, inplace=True)

# %%
df.rename(index=str, columns={"Unnamed: 7": "Latitude", "Unnamed: 10": "Longitude"},inplace=True)

# %%
df.Mo = df.Mo.astype(str)

# %%
df.Mo = df.Mo.replace ({"1": "Jan","2":"Feb","3":"Mar","4":"Apr","5":"May","6":"Jun","7":"Jul"})

# %%
df
# Out:
#       Year   Mo  Dy  Hr  Mn    Sec  Latitude  Longitude  mag  depth
# 0     2018  Jul  10  15  29  15.91   37.6361    23.0872  2.4   10.0
# 1     2018  Jul  10  12  44  45.51   35.8716    24.2618  2.1    5.0
# 2     2018  Jul  10  11  51  25.69   38.5067    21.6012  1.9    5.0
# 3     2018  Jul  10   5  32  47.32   38.3658    21.8209  0.9   12.0
# 4     2018  Jul  10   5  18  19.65   38.5995    22.8017  2.4   10.0
# 5     2018  Jul  10   5  16  50.86   38.5072    22.7486  2.2   10.0
# 6     2018  Jul  10   5  12  58.02   36.5560    23.9036  2.7   10.0
# 7     2018  Jul  10   3  13  43.21   36.5412    24.0659  2.8   10.0
# 8     2018  Jul  10   2  18   0.03   42.2046    18.7619  3.4   10.0
# 9     2018  Jul  10   2  17  26.06   35.3872    23.2067  2.0   10.0
# 10    2018  Jul  10   1  21  22.60   38.2795    22.1807  0.7    5.0
# 11    2018  Jul  10   0  57  15.02   40.5166    23.5795  1.5   10.0
# 12    2018  Jul   9  23  31  27.80   40.4235    23.6209  1.2   19.0
# 13    2018  Jul   9  23  16  22.87   38.2606    22.1800  0.5    5.0
# 14    2018  Jul   9  22  58  50.52   39.9396    22.4796  2.2   10.0
# 15    2018  Jul   9  22  34  50.70   36.1958    25.3040  1.7   72.0
# 16    2018  Jul   9  22  27  48.29   40.1716    24.4633  1.5   10.0
# 17    2018  Jul   9  22  16  33.02   36.8890    26.6266  2.4    9.0
# 18    2018  Jul   9  19   8  35.77   38.5413    24.5944  2.8   10.0
# 19    2018  Jul   9  18  40  53.98   36.7301    21.5026  2.7   10.0
# 20    2018  Jul   9  17  18  20.22   36.6732    21.7834  3.2   10.0
# 21    2018  Jul   9  17   5  31.84   35.7566    22.8315  2.6   10.0
# 22    2018  Jul   9  16  43  17.13   39.5033    20.9917  1.8   10.0
# 23    2018  Jul   9  16  28  49.90   39.2965    23.0181  2.3   25.0
# 24    2018  Jul   9  16  25  47.67   36.7854    21.8249  2.3    5.0
# 25    2018  Jul   9  16  23  18.34   36.6500    21.6097  2.5   10.0
# 26    2018  Jul   9  14   0  24.29   38.4015    20.4471  2.2    5.0
# 27    2018  Jul   9  11  30  28.64   37.3039    21.2605  2.0   10.0
# 28    2018  Jul   9   9  51  23.13   39.4570    26.1031  2.0   10.0
# 29    2018  Jul   9   9  15  50.35   38.7234    20.4196  2.0   11.0
# ...    ...  ...  ..  ..  ..    ...       ...        ...  ...    ...
# 4037  2018  Jan   2   0  49  21.23   38.4533    21.8888  0.6    5.0
# 4038  2018  Jan   1  23   0  47.79   41.2113    22.9381  3.4   10.0
# 4039  2018  Jan   1  22  55  50.63   35.8338    23.2802  2.4    5.0
# 4040  2018  Jan   1  22  26  39.99   38.5318    21.2595  2.0   10.0
# 4041  2018  Jan   1  22  19  14.96   41.1780    22.8887  3.0   10.0
# 4042  2018  Jan   1  22  16  16.04   41.1855    22.9062  3.6   10.0
# 4043  2018  Jan   1  22  13  53.01   41.2483    22.9240  3.9   10.0
# 4044  2018  Jan   1  21  42  28.47   38.5203    21.2599  1.6   10.0
# 4045  2018  Jan   1  20  58  16.20   38.3791    21.8749  1.2    5.0
# 4046  2018  Jan   1  20   1  46.00   39.7766    21.7689  1.8   10.0
# 4047  2018  Jan   1  19  19   9.27   38.4337    22.0650  1.0    5.0
# 4048  2018  Jan   1  18  10  50.03   38.8652    22.4648  1.7   10.0
# 4049  2018  Jan   1  17  17  13.87   38.6959    20.6378  1.7    5.0
# 4050  2018  Jan   1  16  20   8.85   38.4117    21.8038  1.4    6.0
# 4051  2018  Jan   1  16  15  56.57   38.1419    23.4637  1.7   14.0
# 4052  2018  Jan   1  13  56  29.49   39.9105    19.6460  3.3   10.0
# 4053  2018  Jan   1  12  58  20.26   39.3814    22.7572  1.8   10.0
# 4054  2018  Jan   1  10  28  32.26   38.2370    22.6963  1.8    5.0
# 4055  2018  Jan   1  10  16   5.05   38.3164    22.1024  1.5    5.0
# 4056  2018  Jan   1   9  21  51.32   39.5790    23.8567  2.1   10.0
# 4057  2018  Jan   1   9  13  40.35   40.2940    25.1823  2.1   10.0
# 4058  2018  Jan   1   8  28  30.16   38.1178    22.8083  1.6   10.0
# 4059  2018  Jan   1   6  55  51.69   37.9166    21.4443  1.6   10.0
# 4060  2018  Jan   1   5  36  44.99   38.8613    20.3656  1.4   11.0
# 4061  2018  Jan   1   5  12  15.12   38.5108    22.2813  0.9    5.0
# 4062  2018  Jan   1   4  48  26.50   38.0784    22.1278  1.5   31.0
# 4063  2018  Jan   1   4  37  49.00   38.9170    26.5064  2.7   10.0
# 4064  2018  Jan   1   3   5   8.84   38.3889    22.0982  0.2    5.0
# 4065  2018  Jan   1   1  58  53.55   38.8927    21.5551  1.6   17.0
# 4066  2018  Jan   1   0  59  33.19   38.1026    22.6207  1.6   10.0
#
# [4067 rows x 10 columns]

# %%
quakes_df = df

# %%
quakes_df.to_csv ("quakes.csv",index=False)

# %% [markdown]
# ### Graph 1: Which was the month with the most earthquakes in Greece in 2018 [up till today] ?

# %%
most_quakes_month = quakes_df.Mo.value_counts().sort_values(ascending=True)

# %%
most_quakes_month
# Out:
# Jul    285
# Feb    523
# Mar    577
# May    622
# Jun    635
# Apr    670
# Jan    755
# Name: Mo, dtype: int64

# %%
plt.style.use ('fivethirtyeight')
bar_colors = ['#ffbaba','#ffbaba','#ffbaba','#ffbaba','#ffbaba','#ffbaba','#ff0000']
most_quakes = most_quakes_month.plot(kind='barh', color=bar_colors,figsize=(12,7), legend=False)
most_quakes.set_xticks ([0,200,400,600,800])
most_quakes.set_title ("Greece : Earthquakes in 2018", pad = 40)
most_quakes.title.set_fontsize(27)
most_quakes.title.set_fontname("Nevis")
plt.savefig("allquakes.png")

# %% [markdown]
# ### Graph 2: All quakes in Greece in 2018 per magnitude and depth

# %%
df.dropna().depth
# Out:
# 0       10.0
# 1        5.0
# 2        5.0
# 3       12.0
# 4       10.0
# 5       10.0
# 6       10.0
# 7       10.0
# 8       10.0
# 9       10.0
# 10       5.0
# 11      10.0
# 12      19.0
# 13       5.0
# 14      10.0
# 15      72.0
# 16      10.0
# 17       9.0
# 18      10.0
# 19      10.0
# 20      10.0
# 21      10.0
# 22      10.0
# 23      25.0
# 24       5.0
# 25      10.0
# 26       5.0
# 27      10.0
# 28      10.0
# 29      11.0
#         ...
# 4037     5.0
# 4038    10.0
# 4039     5.0
# 4040    10.0
# 4041    10.0
# 4042    10.0
# 4043    10.0
# 4044    10.0
# 4045     5.0
# 4046    10.0
# 4047     5.0
# 4048    10.0
# 4049     5.0
# 4050     6.0
# 4051    14.0
# 4052    10.0
# 4053    10.0
# 4054     5.0
# 4055     5.0
# 4056    10.0
# 4057    10.0
# 4058    10.0
# 4059    10.0
# 4060    11.0
# 4061     5.0
# 4062    31.0
# 4063    10.0
# 4064     5.0
# 4065    17.0
# 4066    10.0
# Name: depth, Length: 4054, dtype: float64

# %%
plt.style.use ('fivethirtyeight')
def get_color(mag):
    if mag >= 3.5: 
        return '#ff0000'
    else:
        return '#ffbaba'

bar_colors = [get_color(mag) for mag in df.dropna().mag]
fig, ax = plt.subplots(figsize=(12,7))
ax.scatter(x=df.dropna().Mo, y=df.dropna().depth, s=100 * df.dropna().mag, color= bar_colors, alpha=0.5)
plt.ylabel('focal depth', fontsize=15)
plt.gca().invert_yaxis()
ax.set_title ("Earthquakes in Greece : Magnitude vs. Depth", pad=70,fontsize=27,fontname="Nevis")
plt.savefig("magvsdepth.png")

# %% [markdown]
# ### Graph 3: All quakes in Greece in 2018 on lattitude axis

# %%
df2 = df[['Latitude','mag','Mo']]

# %%
df2
# Out:
#       Latitude  mag   Mo
# 0      37.6361  2.4  Jul
# 1      35.8716  2.1  Jul
# 2      38.5067  1.9  Jul
# 3      38.3658  0.9  Jul
# 4      38.5995  2.4  Jul
# 5      38.5072  2.2  Jul
# 6      36.5560  2.7  Jul
# 7      36.5412  2.8  Jul
# 8      42.2046  3.4  Jul
# 9      35.3872  2.0  Jul
# 10     38.2795  0.7  Jul
# 11     40.5166  1.5  Jul
# 12     40.4235  1.2  Jul
# 13     38.2606  0.5  Jul
# 14     39.9396  2.2  Jul
# 15     36.1958  1.7  Jul
# 16     40.1716  1.5  Jul
# 17     36.8890  2.4  Jul
# 18     38.5413  2.8  Jul
# 19     36.7301  2.7  Jul
# 20     36.6732  3.2  Jul
# 21     35.7566  2.6  Jul
# 22     39.5033  1.8  Jul
# 23     39.2965  2.3  Jul
# 24     36.7854  2.3  Jul
# 25     36.6500  2.5  Jul
# 26     38.4015  2.2  Jul
# 27     37.3039  2.0  Jul
# 28     39.4570  2.0  Jul
# 29     38.7234  2.0  Jul
# ...        ...  ...  ...
# 4037   38.4533  0.6  Jan
# 4038   41.2113  3.4  Jan
# 4039   35.8338  2.4  Jan
# 4040   38.5318  2.0  Jan
# 4041   41.1780  3.0  Jan
# 4042   41.1855  3.6  Jan
# 4043   41.2483  3.9  Jan
# 4044   38.5203  1.6  Jan
# 4045   38.3791  1.2  Jan
# 4046   39.7766  1.8  Jan
# 4047   38.4337  1.0  Jan
# 4048   38.8652  1.7  Jan
# 4049   38.6959  1.7  Jan
# 4050   38.4117  1.4  Jan
# 4051   38.1419  1.7  Jan
# 4052   39.9105  3.3  Jan
# 4053   39.3814  1.8  Jan
# 4054   38.2370  1.8  Jan
# 4055   38.3164  1.5  Jan
# 4056   39.5790  2.1  Jan
# 4057   40.2940  2.1  Jan
# 4058   38.1178  1.6  Jan
# 4059   37.9166  1.6  Jan
# 4060   38.8613  1.4  Jan
# 4061   38.5108  0.9  Jan
# 4062   38.0784  1.5  Jan
# 4063   38.9170  2.7  Jan
# 4064   38.3889  0.2  Jan
# 4065   38.8927  1.6  Jan
# 4066   38.1026  1.6  Jan
#
# [4067 rows x 3 columns]

# %%
plt.style.use ('fivethirtyeight')
ax = df2.plot(y='Latitude', x='mag', marker='o', linestyle='', markersize=9, figsize=(17,10),label='_nolabel_',alpha=0.3)
ax_Ath = plt.axhline(y=37.9838, color='#282828', linestyle=':',alpha = 1, label = 'Athens Latitude')
ax.legend(fontsize=15, loc=2)
ax.set_title ("2018 Earthquakes in Greece: North vs. South", pad = 30)
ax.title.set_fontsize(30)
ax.grid(True, axis = 'x', linestyle =":", linewidth=1)
ax.title.set_fontname("Nevis")
plt.xlabel('Magnitude (in Richter Scale)',labelpad=30)
ax.xaxis.label.set_visible(True)
plt.savefig("northvssouth.png")
# Out:
# /Users/nickospi/.pyenv/versions/3.6.5/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x111576550> has a label of '_nolabel_' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %% [markdown]
# ### Graph 4. [wannabe Animated] quakes per second

# %%
''.join(df['Year'].tolist()+df['Mo'].tolist()+df['Dy'].tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-64f60a1bdfaa> in <module>()
# ----> 1 ''.join(df['Year'].tolist()+df['Mo'].tolist()+df['Dy'].tolist())
#
# TypeError: sequence item 0: expected str instance, int found

# %%
df ['date'] = df['Year'].append(df.Dy)#,df.Hr,df.Mn,df.Sec])

# %%
df #months back in int

# %%
plt.style.use ('fivethirtyeight')


from matplotlib import animation
ax = df.plot(y='mag', marker='o', linestyle='', markersize=8, figsize=(17,10),alpha=0.3,legend=False)
ax.set_title ("2018 Earthquakes in Greece: As they happened", pad = 30)
ax.title.set_fontsize(30)
ax.title.set_fontname("Nevis")
plt.ylabel('Magnitude (in Richter Scale)',labelpad=30)
ax.yaxis.label.set_visible(True)
plt.savefig("astheyhappened.png")

# %% [markdown]
# ## Nice to have :
#
# ### - a map showing earthquakes in Greece and focal points/mag
# ### - a graph with the actual names of the big cities with most quakes in a range (eg. 50 mi)
# ### - a graph showing how the most quakes that have happened in a minimum timeframe (like a minute or an hour - the df shows quakes per second). Animate that graph.
# ### - would like to work more on the legends [the warning in the 3rd one is about the legend]
